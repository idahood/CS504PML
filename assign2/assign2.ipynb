# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import register_matplotlib_converters

from datetime import datetime,timedelta

# %% [markdown]
# # Homework 2: Predicting the COVID-19 Peak
# In this homework, we are going to use regression to learn the infection curve of the COVID-19 in the US, and help answer the following questions
#
# 1. When the US will reach the peak of COVID-19 cases?
# 2. How many people are estimated to be infected in the US?
# 3. Have we passed the inflection point？
#
# Add your code to the following sections in the template.
# ```python
#
#     ## add your code here
#
#     ##
# ```
#
# ### Student information
#     1. Your name: Steven Dodd
#     2. Department: CS
#     3. Graduate
#
# ### TA grading: XX/100
#     1. 1?/10
#     2. 2?/30
#     3. 3: ?/10
#     4. 4: ?/30
#     5. 5: ?/20

# %%
# load data from JHU CSSE 
# https://github.com/CSSEGISandData/COVID-19
url_confirmed = 'https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_confirmed_global.csv'
df_confirmed=pd.read_csv(url_confirmed, index_col=[0,1,2,3])
df_confirmed
# Out:
#                                                                        1/22/20  ...  4/20/20
# Province/State            Country/Region        Lat        Long                 ...
# NaN                       Afghanistan            33.000000  65.000000        0  ...     1026
#                           Albania                41.153300  20.168300        0  ...      584
#                           Algeria                28.033900  1.659600         0  ...     2718
#                           Andorra                42.506300  1.521800         0  ...      717
#                           Angola                -11.202700  17.873900        0  ...       24
# ...                                                                        ...  ...      ...
# Saint Pierre and Miquelon France                 46.885200 -56.315900        0  ...        1
# NaN                       South Sudan            6.877000   31.307000        0  ...        4
#                           Western Sahara         24.215500 -12.885800        0  ...        6
#                           Sao Tome and Principe  0.186360   6.613081         0  ...        4
#                           Yemen                  15.552727  48.516388        0  ...        1
#
# [264 rows x 90 columns]

# %%
# show the date range
dates= [datetime.strptime(d, '%m/%d/%y') for d in df_confirmed.columns.values]
date_range = pd.DatetimeIndex(dates)
date_range
# Out:
# DatetimeIndex(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25',
#                '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29',
#                '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02',
#                '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#                '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#                '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14',
#                '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18',
#                '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22',
#                '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26',
#                '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#                '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#                '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#                '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
#                '2020-03-14', '2020-03-15', '2020-03-16', '2020-03-17',
#                '2020-03-18', '2020-03-19', '2020-03-20', '2020-03-21',
#                '2020-03-22', '2020-03-23', '2020-03-24', '2020-03-25',
#                '2020-03-26', '2020-03-27', '2020-03-28', '2020-03-29',
#                '2020-03-30', '2020-03-31', '2020-04-01', '2020-04-02',
#                '2020-04-03', '2020-04-04', '2020-04-05', '2020-04-06',
#                '2020-04-07', '2020-04-08', '2020-04-09', '2020-04-10',
#                '2020-04-11', '2020-04-12', '2020-04-13', '2020-04-14',
#                '2020-04-15', '2020-04-16', '2020-04-17', '2020-04-18',
#                '2020-04-19', '2020-04-20'],
#               dtype='datetime64[ns]', freq=None)

# %%
# Select data from a list of countries
# Using at least 100 cases to define the outbreak of COVID-19 in a country

all_countries = np.unique(df_confirmed.index.get_level_values('Country/Region').values)
min_cases = 100 # Using at least 100 cases to define the outbreak of COVID-19 in a country

cases = {}
confirmed_selected = {}
for country in all_countries:
    cou = df_confirmed.loc[pd.IndexSlice[:, country], :].sum()
    cases[country] = cou[cou > min_cases] 
    dates = [datetime.strptime(date, '%m/%d/%y') for date in cases[country].index]
    confirmed_selected[country] = pd.DataFrame(cases[country], columns=['Cases'], index=dates)
    confirmed_selected[country]['DayCount'] = np.arange(1,cases[country].shape[0]+1)
    print(country)
    if len(cases[country]) > 0:
        print(' Outbreak:', confirmed_selected[country].index[0], 'Current cases: ',\
              confirmed_selected[country]['Cases'][-1])
# Out:
# Afghanistan
#  Outbreak: 2020-03-27 00:00:00 Current cases:  1026
# Albania
#  Outbreak: 2020-03-23 00:00:00 Current cases:  584
# Algeria
#  Outbreak: 2020-03-21 00:00:00 Current cases:  2718
# Andorra
#  Outbreak: 2020-03-22 00:00:00 Current cases:  717
# Angola
# Antigua and Barbuda
# Argentina
#  Outbreak: 2020-03-20 00:00:00 Current cases:  2941
# Armenia
#  Outbreak: 2020-03-19 00:00:00 Current cases:  1339
# Australia
#  Outbreak: 2020-03-10 00:00:00 Current cases:  6547
# Austria
#  Outbreak: 2020-03-08 00:00:00 Current cases:  14795
# Azerbaijan
#  Outbreak: 2020-03-26 00:00:00 Current cases:  1436
# Bahamas
# Bahrain
#  Outbreak: 2020-03-10 00:00:00 Current cases:  1907
# Bangladesh
#  Outbreak: 2020-04-06 00:00:00 Current cases:  2948
# Barbados
# Belarus
#  Outbreak: 2020-03-30 00:00:00 Current cases:  6264
# Belgium
#  Outbreak: 2020-03-06 00:00:00 Current cases:  39983
# Belize
# Benin
# Bhutan
# Bolivia
#  Outbreak: 2020-03-31 00:00:00 Current cases:  564
# Bosnia and Herzegovina
#  Outbreak: 2020-03-22 00:00:00 Current cases:  1309
# Botswana
# Brazil
#  Outbreak: 2020-03-13 00:00:00 Current cases:  40743
# Brunei
#  Outbreak: 2020-03-24 00:00:00 Current cases:  138
# Bulgaria
#  Outbreak: 2020-03-20 00:00:00 Current cases:  929
# Burkina Faso
#  Outbreak: 2020-03-24 00:00:00 Current cases:  581
# Burma
#  Outbreak: 2020-04-19 00:00:00 Current cases:  119
# Burundi
# Cabo Verde
# Cambodia
#  Outbreak: 2020-03-29 00:00:00 Current cases:  122
# Cameroon
#  Outbreak: 2020-03-29 00:00:00 Current cases:  1163
# Canada
#  Outbreak: 2020-03-11 00:00:00 Current cases:  37657
# Central African Republic
# Chad
# Chile
#  Outbreak: 2020-03-16 00:00:00 Current cases:  10507
# China
#  Outbreak: 2020-01-22 00:00:00 Current cases:  83817
# Colombia
#  Outbreak: 2020-03-19 00:00:00 Current cases:  3977
# Congo (Brazzaville)
#  Outbreak: 2020-04-15 00:00:00 Current cases:  160
# Congo (Kinshasa)
#  Outbreak: 2020-04-01 00:00:00 Current cases:  332
# Costa Rica
#  Outbreak: 2020-03-21 00:00:00 Current cases:  662
# Cote d'Ivoire
#  Outbreak: 2020-03-27 00:00:00 Current cases:  847
# Croatia
#  Outbreak: 2020-03-19 00:00:00 Current cases:  1881
# Cuba
#  Outbreak: 2020-03-28 00:00:00 Current cases:  1087
# Cyprus
#  Outbreak: 2020-03-23 00:00:00 Current cases:  772
# Czechia
#  Outbreak: 2020-03-13 00:00:00 Current cases:  6900
# Denmark
#  Outbreak: 2020-03-10 00:00:00 Current cases:  7711
# Diamond Princess
#  Outbreak: 2020-02-10 00:00:00 Current cases:  712
# Djibouti
#  Outbreak: 2020-04-08 00:00:00 Current cases:  846
# Dominica
# Dominican Republic
#  Outbreak: 2020-03-21 00:00:00 Current cases:  4964
# Ecuador
#  Outbreak: 2020-03-18 00:00:00 Current cases:  10128
# Egypt
#  Outbreak: 2020-03-14 00:00:00 Current cases:  3333
# El Salvador
#  Outbreak: 2020-04-09 00:00:00 Current cases:  218
# Equatorial Guinea
# Eritrea
# Estonia
#  Outbreak: 2020-03-14 00:00:00 Current cases:  1535
# Eswatini
# Ethiopia
#  Outbreak: 2020-04-18 00:00:00 Current cases:  111
# Fiji
# Finland
#  Outbreak: 2020-03-13 00:00:00 Current cases:  3868
# France
#  Outbreak: 2020-03-01 00:00:00 Current cases:  156480
# Gabon
#  Outbreak: 2020-04-17 00:00:00 Current cases:  120
# Gambia
# Georgia
#  Outbreak: 2020-03-30 00:00:00 Current cases:  402
# Germany
#  Outbreak: 2020-03-01 00:00:00 Current cases:  147065
# Ghana
#  Outbreak: 2020-03-26 00:00:00 Current cases:  1042
# Greece
#  Outbreak: 2020-03-13 00:00:00 Current cases:  2245
# Grenada
# Guatemala
#  Outbreak: 2020-04-10 00:00:00 Current cases:  289
# Guinea
#  Outbreak: 2020-04-04 00:00:00 Current cases:  622
# Guinea-Bissau
# Guyana
# Haiti
# Holy See
# Honduras
#  Outbreak: 2020-03-29 00:00:00 Current cases:  477
# Hungary
#  Outbreak: 2020-03-21 00:00:00 Current cases:  1984
# Iceland
#  Outbreak: 2020-03-12 00:00:00 Current cases:  1773
# India
#  Outbreak: 2020-03-14 00:00:00 Current cases:  18539
# Indonesia
#  Outbreak: 2020-03-15 00:00:00 Current cases:  6760
# Iran
#  Outbreak: 2020-02-26 00:00:00 Current cases:  83505
# Iraq
#  Outbreak: 2020-03-13 00:00:00 Current cases:  1574
# Ireland
#  Outbreak: 2020-03-14 00:00:00 Current cases:  15652
# Israel
#  Outbreak: 2020-03-13 00:00:00 Current cases:  13713
# Italy
#  Outbreak: 2020-02-23 00:00:00 Current cases:  181228
# Jamaica
#  Outbreak: 2020-04-15 00:00:00 Current cases:  223
# Japan
#  Outbreak: 2020-02-21 00:00:00 Current cases:  10797
# Jordan
#  Outbreak: 2020-03-22 00:00:00 Current cases:  425
# Kazakhstan
#  Outbreak: 2020-03-26 00:00:00 Current cases:  1852
# Kenya
#  Outbreak: 2020-04-02 00:00:00 Current cases:  281
# Korea, South
#  Outbreak: 2020-02-20 00:00:00 Current cases:  10674
# Kosovo
#  Outbreak: 2020-03-31 00:00:00 Current cases:  510
# Kuwait
#  Outbreak: 2020-03-14 00:00:00 Current cases:  1995
# Kyrgyzstan
#  Outbreak: 2020-03-31 00:00:00 Current cases:  568
# Laos
# Latvia
#  Outbreak: 2020-03-20 00:00:00 Current cases:  739
# Lebanon
#  Outbreak: 2020-03-15 00:00:00 Current cases:  677
# Liberia
# Libya
# Liechtenstein
# Lithuania
#  Outbreak: 2020-03-22 00:00:00 Current cases:  1326
# Luxembourg
#  Outbreak: 2020-03-17 00:00:00 Current cases:  3558
# MS Zaandam
# Madagascar
#  Outbreak: 2020-04-11 00:00:00 Current cases:  121
# Malawi
# Malaysia
#  Outbreak: 2020-03-09 00:00:00 Current cases:  5425
# Maldives
# Mali
#  Outbreak: 2020-04-12 00:00:00 Current cases:  246
# Malta
#  Outbreak: 2020-03-23 00:00:00 Current cases:  431
# Mauritania
# Mauritius
#  Outbreak: 2020-03-28 00:00:00 Current cases:  328
# Mexico
#  Outbreak: 2020-03-19 00:00:00 Current cases:  8261
# Moldova
#  Outbreak: 2020-03-23 00:00:00 Current cases:  2548
# Monaco
# Mongolia
# Montenegro
#  Outbreak: 2020-03-31 00:00:00 Current cases:  312
# Morocco
#  Outbreak: 2020-03-22 00:00:00 Current cases:  3046
# Mozambique
# Namibia
# Nepal
# Netherlands
#  Outbreak: 2020-03-06 00:00:00 Current cases:  33588
# New Zealand
#  Outbreak: 2020-03-22 00:00:00 Current cases:  1440
# Nicaragua
# Niger
#  Outbreak: 2020-04-03 00:00:00 Current cases:  648
# Nigeria
#  Outbreak: 2020-03-29 00:00:00 Current cases:  665
# North Macedonia
#  Outbreak: 2020-03-22 00:00:00 Current cases:  1225
# Norway
#  Outbreak: 2020-03-06 00:00:00 Current cases:  7156
# Oman
#  Outbreak: 2020-03-26 00:00:00 Current cases:  1410
# Pakistan
#  Outbreak: 2020-03-16 00:00:00 Current cases:  8418
# Panama
#  Outbreak: 2020-03-19 00:00:00 Current cases:  4467
# Papua New Guinea
# Paraguay
#  Outbreak: 2020-04-05 00:00:00 Current cases:  208
# Peru
#  Outbreak: 2020-03-17 00:00:00 Current cases:  16325
# Philippines
#  Outbreak: 2020-03-14 00:00:00 Current cases:  6459
# Poland
#  Outbreak: 2020-03-14 00:00:00 Current cases:  9593
# Portugal
#  Outbreak: 2020-03-13 00:00:00 Current cases:  20863
# Qatar
#  Outbreak: 2020-03-11 00:00:00 Current cases:  6015
# Romania
#  Outbreak: 2020-03-14 00:00:00 Current cases:  8936
# Russia
#  Outbreak: 2020-03-17 00:00:00 Current cases:  47121
# Rwanda
#  Outbreak: 2020-04-04 00:00:00 Current cases:  147
# Saint Kitts and Nevis
# Saint Lucia
# Saint Vincent and the Grenadines
# San Marino
#  Outbreak: 2020-03-15 00:00:00 Current cases:  462
# Sao Tome and Principe
# Saudi Arabia
#  Outbreak: 2020-03-14 00:00:00 Current cases:  10484
# Senegal
#  Outbreak: 2020-03-26 00:00:00 Current cases:  377
# Serbia
#  Outbreak: 2020-03-19 00:00:00 Current cases:  6630
# Seychelles
# Sierra Leone
# Singapore
#  Outbreak: 2020-02-29 00:00:00 Current cases:  8014
# Slovakia
#  Outbreak: 2020-03-18 00:00:00 Current cases:  1173
# Slovenia
#  Outbreak: 2020-03-13 00:00:00 Current cases:  1335
# Somalia
#  Outbreak: 2020-04-17 00:00:00 Current cases:  237
# South Africa
#  Outbreak: 2020-03-18 00:00:00 Current cases:  3300
# South Sudan
# Spain
#  Outbreak: 2020-03-02 00:00:00 Current cases:  200210
# Sri Lanka
#  Outbreak: 2020-03-24 00:00:00 Current cases:  304
# Sudan
#  Outbreak: 2020-04-20 00:00:00 Current cases:  107
# Suriname
# Sweden
#  Outbreak: 2020-03-06 00:00:00 Current cases:  14777
# Switzerland
#  Outbreak: 2020-03-05 00:00:00 Current cases:  27944
# Syria
# Taiwan*
#  Outbreak: 2020-03-19 00:00:00 Current cases:  422
# Tanzania
#  Outbreak: 2020-04-17 00:00:00 Current cases:  254
# Thailand
#  Outbreak: 2020-03-15 00:00:00 Current cases:  2792
# Timor-Leste
# Togo
# Trinidad and Tobago
#  Outbreak: 2020-04-04 00:00:00 Current cases:  114
# Tunisia
#  Outbreak: 2020-03-24 00:00:00 Current cases:  884
# Turkey
#  Outbreak: 2020-03-19 00:00:00 Current cases:  90980
# US
#  Outbreak: 2020-03-03 00:00:00 Current cases:  784326
# Uganda
# Ukraine
#  Outbreak: 2020-03-25 00:00:00 Current cases:  5710
# United Arab Emirates
#  Outbreak: 2020-03-18 00:00:00 Current cases:  7265
# United Kingdom
#  Outbreak: 2020-03-05 00:00:00 Current cases:  125856
# Uruguay
#  Outbreak: 2020-03-21 00:00:00 Current cases:  535
# Uzbekistan
#  Outbreak: 2020-03-28 00:00:00 Current cases:  1627
# Venezuela
#  Outbreak: 2020-03-26 00:00:00 Current cases:  256
# Vietnam
#  Outbreak: 2020-03-22 00:00:00 Current cases:  268
# West Bank and Gaza
#  Outbreak: 2020-03-29 00:00:00 Current cases:  449
# Western Sahara
# Yemen
# Zambia
# Zimbabwe

# %%
#1. plot the infection curves. 10 points

# plot the raw records of ['US', 'Italy','China'] with un-aligned date
countries = ['US', 'Italy','China']
for country in countries:
    dates=confirmed_selected[country].index
    plt.plot(dates, np.array(list(confirmed_selected[country]['Cases'].values)), label=country)
    plt.legend(loc='upper left')
    plt.tick_params(rotation=45, labelsize=12)
    plt.ylabel('Confirmed', fontsize=14)
plt.xlim([dates[0]-np.timedelta64(3,'D'), dates[-1]+np.timedelta64(10,'D')])
plt.title('Unaligned Curves')
plt.show()

# plot the records of ['US', 'Italy','China'] with aligned outbreak date (from day 1 to current day)
## add your code here. 10 points
countries = ['US', 'Italy','China']
for country in countries:
    dates=confirmed_selected[country].index
    plt.plot(dates-dates[0], np.array(list(confirmed_selected[country]['Cases'].values)), label=country)
    plt.legend(loc='upper left')
    plt.tick_params(rotation=45, labelsize=12)
    plt.ylabel('Confirmed', fontsize=14)
    plt.xlabel('Days', fontsize=14)
plt.title('Aligned Curves')
plt.show()
##

# %%
#2. implement the logistic and exponential models. 30 points

# 2.1 complete the logistic function. 10 points
def logistic_model(x,a,b,n):
    '''the logistic model
    
        parameters
        ----------
        x: input day
        a: 1/growth rate
        b: inflection point
        n: possible max cases
        
        return
        log_model
    '''
    ## add your code here
    log_model = n / (1 + np.exp(-(1/a)*(x-b)))

    return log_model
    ##
    
#2.2 complete the exponential function. 10 points
def exp_model(x,p,N0=3,X0=1):
    '''the exponential model

        parameters
        ----------
        x: input day
        p: growth rate
        N0: initial case for day 1
        X0: starting day
        
        return
            exp_model
    '''
    ## add your code here
    exp_model = N0 * (1 + p)**(x-X0)

    return exp_model
    ##

# 2.3 plot the the logistic and exponential functions with growth rate 0.23. 10 points
# logistic_model(x, 1/0.23, 50, 100000)
# exp_model(x, 0.23)

x= np.linspace(0,100,100) #input of the horizontal axis 
## add your code here
plt.plot(x, logistic_model(x, 1/0.23, 50, 100000), label="log_model")
plt.plot(x, exp_model(x, 0.23), label="exp_model")
##
plt.legend()
plt.xlabel('Days')
plt.ylabel('Cases')
plt.ylim(-1000,150000)
# Out:
# (-1000.0, 150000.0)

# %%
# select US data and prepare the traing and test dataset
# US confirmed cases from the outbreak date
country = 'US'
print(confirmed_selected[country])

# training and test data
leaveout = -3 # leave out 5 days for test 
x_train = np.array(list(confirmed_selected[country]['DayCount'].values))[:leaveout]
y_train = np.array(list(confirmed_selected[country]['Cases'].values))[:leaveout]    

x_test = np.array(list(confirmed_selected[country]['DayCount'].values))[leaveout:]
y_test = np.array(list(confirmed_selected[country]['Cases'].values))[leaveout:]
# Out:
#              Cases  DayCount
# 2020-03-03     118         1
# 2020-03-04     149         2
# 2020-03-05     217         3
# 2020-03-06     262         4
# 2020-03-07     402         5
# 2020-03-08     518         6
# 2020-03-09     583         7
# 2020-03-10     959         8
# 2020-03-11    1281         9
# 2020-03-12    1663        10
# 2020-03-13    2179        11
# 2020-03-14    2727        12
# 2020-03-15    3499        13
# 2020-03-16    4632        14
# 2020-03-17    6421        15
# 2020-03-18    7783        16
# 2020-03-19   13747        17
# 2020-03-20   19273        18
# 2020-03-21   25600        19
# 2020-03-22   33276        20
# 2020-03-23   43843        21
# 2020-03-24   53736        22
# 2020-03-25   65778        23
# 2020-03-26   83836        24
# 2020-03-27  101657        25
# 2020-03-28  121465        26
# 2020-03-29  140909        27
# 2020-03-30  161831        28
# 2020-03-31  188172        29
# 2020-04-01  213372        30
# 2020-04-02  243762        31
# 2020-04-03  275586        32
# 2020-04-04  308853        33
# 2020-04-05  337072        34
# 2020-04-06  366667        35
# 2020-04-07  397505        36
# 2020-04-08  429052        37
# 2020-04-09  462780        38
# 2020-04-10  496535        39
# 2020-04-11  526396        40
# 2020-04-12  555313        41
# 2020-04-13  580619        42
# 2020-04-14  607670        43
# 2020-04-15  636350        44
# 2020-04-16  667592        45
# 2020-04-17  699706        46
# 2020-04-18  732197        47
# 2020-04-19  759086        48
# 2020-04-20  784326        49

# %%
#3. train the logistic model curve_fit in scipy.optimize and print out the parameters (a, b, n). 10 points
from scipy.optimize import curve_fit

print('Train the logistic model')
## add your code here
popt, pcov = curve_fit(logistic_model, x_train, y_train)
plt.plot(x_train, y_train, 'b-', label='data')
plt.plot(x_train, logistic_model(x_train, *popt), 'r-', label='fit: a=%5.3f, b=%5.3f, n=%5.3f' % tuple(popt))
plt.legend()
plt.show()
(a, b, n) = popt
print(f'a={a}, b={b}, n={n}')

##
# Out:
# Train the logistic model
# a=5.557815769616422, b=35.721168403819156, n=782519.1810148384

# %%
# 4. prediction and evaulation. 30 points
import sklearn.metrics as sklm

# 4.1 complete the following evaluate function to calculate the mean squared log error, 
# mean squared error and the R^2. 10 points
def my_evaluation(y, y_pred):
    ## add your code here
    mse = sklm.mean_squared_error(y, y_pred)
    mse_log = sklm.mean_squared_log_error(y, y_pred)
    r2 = sklm.r2_score(y, y_pred)
    ##
    return mse, mse_log, r2

# 4.2 calculate and print out the mse, mse_log and r2 for both the training and test sets. 20 points
## add your code here
print(my_evaluation(y_train, logistic_model(x_train, a, b, n)))
print(my_evaluation(y_test, logistic_model(x_test, a, b, n)))
##
# Out:
# (69803592.58900794, 1.1572804324254045, 0.99864274846056)
# (3040121125.1009865, 0.005599121466501353, -5.710247130048548)

# %%
# 5. Results visualization. 20 ponts
# 5.1. plot the real infection curve vs. the predicted infection curve
# 5.2. print out the estimated total number of COVID-19 cases that will be confirmed and 
# print out the date that we will reach the end (max number) 

# 5.1 curves. 10 points
## add your code here
dates=confirmed_selected['US'].index
plt.plot(dates, np.array(list(confirmed_selected['US']['Cases'].values)), label='Real')
plt.plot([dates[0] + np.timedelta64(i,'D') for i in range (0, 120)], logistic_model([i for i in range (0, 120)], *popt), label='Predicted')
plt.tick_params(rotation=45, labelsize=12)
plt.legend(loc='lower right') 
plt.show()
##

# 5.2 estimated total number and when. 10 points
## add your code here
target = np.floor(n)
print(f'Estimated total: {target}')
day = 0
while(logistic_model(day, *popt) < target):
    day += 1

print(f"On {dates[0]+np.timedelta64(day,'D')}")
##
# Out:
# Estimated total: 782519.0
# On 2020-07-02 00:00:00
